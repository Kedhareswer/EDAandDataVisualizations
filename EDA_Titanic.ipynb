# %%
#EDA #importing lib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#connect the data
df2=pd.read_csv('titanic3.csv')

# %%
df2
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df2.shape
# Out:
# (1309, 14)

# %%
#inspecting the data
df2.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#      age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# ...

# %%
df2.tail(10)
# Out:
#       pclass  survived                                     name     sex   age  \
# 1299       3         0                      Yasbeck, Mr. Antoni    male  27.0
# 1300       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
# 1301       3         0                     Youseff, Mr. Gerious    male  45.5
# 1302       3         0                        Yousif, Mr. Wazli    male   NaN
# 1303       3         0                    Yousseff, Mr. Gerious    male   NaN
# 1304       3         0                     Zabour, Miss. Hileni  female  14.5
# 1305       3         0                    Zabour, Miss. Thamine  female   NaN
# 1306       3         0                Zakarian, Mr. Mapriededer    male  26.5
# 1307       3         0                      Zakarian, Mr. Ortin    male  27.0
# 1308       3         0                       Zimmerman, Mr. Leo    male  29.0
#
#       sibsp  parch  ticket     fare cabin embarked boat   body home.dest
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
df2.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
df2.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
#Data Preprocessing

#Data Cleaning
#Data Formating

# %%
#Data Cleaning
#2 --> null values
#outliers
#Treating null values
#null values greater than 40% --> the column will be dropped
#null values will be less than 5%--> we can drop the null values
#null values will be between 5 to 40-->#replace the values with either mean / median (depending on presence of outliers)

# %%
#percentage null values
n=df2.shape[0]
drop_col=[]
for i in df2.columns:
    x=df2[i].isnull().sum()
    print(i,(x/n)*100)
    if ((x/n)*100)>40:
        drop_col.append(i)
# Out:
# pclass 0.0
# survived 0.0
# name 0.0
# sex 0.0
# age 20.091673032849503
# sibsp 0.0
# parch 0.0
# ticket 0.0
# fare 0.07639419404125286
# cabin 77.46371275783041
# embarked 0.15278838808250572
# boat 62.87242169595111
# body 90.75630252100841
# home.dest 43.086325439266616

# %% [markdown]
# The first line n = df2.shape[0] assigns the number of rows in the DataFrame to the variable n. This will be used to calculate the percentage of null values in each column.
# The next line drop_col = [] creates an empty list called drop_col. This list will be used to store the names of any columns that need to be dropped due to having a high percentage of null values.
# The for loop iterates over each column in the DataFrame. For each column, the following steps are performed:
# The number of null values in the column is calculated using the isnull() and sum() methods.
# The percentage of null values in the column is calculated by dividing the number of null values by n and multiplying by 100.
# The percentage of null values is printed to the console.
# If the percentage of null values in the column is greater than 40, the column name is appended to the drop_col list.
# After the for loop has finished executing, the drop_col list will contain the names of any columns that need to be dropped. These columns can then be dropped from the DataFrame using the drop() method.

# %%
(x/n)*100
# Out:
# 43.086325439266616

# %%
#dropping columns above 40% of the data
df2.drop(drop_col,axis=1,inplace=True)

# %%
df2
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare embarked
# ...

# %%
for i in df2.columns:
    x=df2[i].isnull().sum()
    print(i,(x/n)*100)
# Out:
# pclass 0.0
# survived 0.0
# name 0.0
# sex 0.0
# age 20.091673032849503
# sibsp 0.0
# parch 0.0
# ticket 0.0
# fare 0.07639419404125286
# embarked 0.15278838808250572

# %%
df2.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# The boxplot diagram of the titanic.csv dataset shows the distribution of the following variables:
#
# Survived: Whether or not the passenger survived the sinking of the Titanic.
# Age: The age of the passenger in years.
# Parch: The number of parents or children of the passenger aboard the Titanic.
# The boxplot shows the five-number summary of each variable: the minimum, the first quartile, the median, the third quartile, and the maximum. The box itself represents the interquartile range (IQR), which is the range between the first and third quartiles. The whiskers extend from the edges of the box to the minimum and maximum values, excluding any outliers. Outliers are defined as points that fall outside of the "whiskers", i.e., more than 1.5 IQRs away from the median.
#
# Survived
#
# The boxplot for the Survived variable shows that the median passenger survived the sinking of the Titanic. The IQR is 1, which means that 50% of the passengers survived. The whiskers extend to 0 and 1, respectively. There are a few outliers, which are most likely passengers who were either very young or very old.
#
# Age
#
# The boxplot for the Age variable shows that the median passenger on the Titanic was 28 years old. The IQR is 20 years old, which means that 50% of the passengers were between the ages of 20 and 40. The whiskers extend to 4 years old and 80 years old, respectively. There are a few outliers, which are most likely children and the elderly.
#
# Parch
#
# The boxplot for the Parch variable shows that the median passenger on the Titanic had no parents or children aboard the ship. The IQR is 1, which means that 50% of the passengers had either 0 or 1 parents or children aboard the ship. The whiskers extend to 0 and 3, respectively. There are a few outliers, which are most likely families with many children.
#
# Overall, the boxplot diagram of the titanic.csv dataset provides a useful summary of the distribution of the Survived, Age, and Parch variables. It shows the median, IQR, and any outliers for each variable. The boxplot can also be used to compare the distributions of different groups. For example, we could compare the distribution of age for male and female passengers on the Titanic.

# %%
#whether the col is numerical or object

#age is having outliers ,,fill the missing values with median else mean
#embarked outliers are not there #embarked is categorical #mode

# %%
#filling missing
print(df2.age)
df2['embarked']=df2['embarked'].fillna(df2['embarked'].mode)
df2['age']=df2['age'].fillna(df2['age'].median())
# Out:
# 0       29.00
# 1        0.92
# 2        2.00
# 3       30.00
# 4       25.00
#         ...
# 1304    14.50
# 1305      NaN
# 1306    26.50
# 1307    27.00
# 1308    29.00
# Name: age, Length: 1309, dtype: float64

# %%
#dropping the null value
df2.dropna(inplace=True)

# %% [markdown]
# The inplace=True parameter in the df2.dropna() function tells the function to modify the DataFrame df2 in place. This means that the function will not return a new DataFrame, but will instead modify the existing DataFrame.

# %%
df2.isnull().sum()
# Out:
# pclass      0
# survived    0
# name        0
# sex         0
# age         0
# sibsp       0
# parch       0
# ticket      0
# fare        0
# embarked    0
# dtype: int64

# %%
#
#IQR
q1=df2['age'].quantile(0.25)
q2 = df2['age'].median()
q3 = df2['age'].quantile(0.75)
iqr = q3 - q1
iqr
# Out:
# 13.0

# %% [markdown]
# The above code calculates the interquartile range (IQR) of the Age column in the DataFrame df2. The IQR is a measure of the spread of the middle 50% of the data. It is calculated by subtracting the first quartile (Q1) from the third quartile (Q3).
#
# The first quartile is the median of the lower half of the data, and the third quartile is the median of the upper half of the data.
#
# To calculate the IQR, the code first sorts the Age column in ascending order. Then, it calculates the first quartile and third quartile using the quantile() method. Finally, it calculates the IQR by subtracting the first quartile from the third quartile.

# %%
iqr=q3-q1

# %%
iqr
lower=q1-1.5*iqr
high=q3+1.5*iqr

# %% [markdown]
# calculates the lower and upper fences for outliers using the interquartile range (IQR).
#
# The IQR is a measure of the spread of the middle 50% of the data. It is calculated by subtracting the first quartile (Q1) from the third quartile (Q3).
#
# The first quartile is the median of the lower half of the data, and the third quartile is the median of the upper half of the data.
#
# To calculate the lower and upper fences, the code first subtracts 1.5 times the IQR from Q1 and adds 1.5 times the IQR to Q3. Any values that fall outside of the lower and upper fences are considered to be outliers.

# %%
lower
# Out:
# 2.5

# %%
high
# Out:
# 54.5

# %%
np.where(df2['age']>high)#which function can be used to check / search a value
# Out:
# (array([   6,    9,   14,   33,   42,   43,   50,   61,   78,   79,   81,
#           83,  115,  116,  123,  135,  139,  154,  158,  174,  186,  192,
#          205,  210,  215,  217,  221,  233,  246,  252,  264,  266,  267,
#          276,  279,  284,  285,  286,  287,  300,  303,  304,  305,  308,
#          310,  321,  330,  351,  432,  441,  455,  456,  472,  487,  490,
#          506,  511,  561,  594,  727,  736,  782, 1015, 1068, 1234, 1260]),)

# %%
#2--> drop , #replace(
df2['age']=df2['age'].replace(np.where(df2['age']>high),df2['age'].median()) #/np.nan
df2['age'].isnull().sum()
# Out:
# 0

# %%
df2['age'].fillna(df2['age'].median(),inplace=True)

# %%
df2
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare embarked
# ...

# %%
df2['sex']=df2['sex'].replace('female',1)
df2['sex']=df2['sex'].replace('male',0)

# %%
df2
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare embarked
# ...

# %%
#Analysis
#Univariant --> analysis of single column
#Bivariant --> analysis of two columns
#Multivariant--> analysis of more than 2 col

# %%
#data type of col--> numerical / categorical
#if its categorical then we go for pie chart // value_counts()
print(df2['survived'].value_counts())
#500 people survived out of 1308
df2['age'].plot(kind='hist')
bins= [0,18,50,70,110]
labels = ['Under_18','Adult','Middle-edged','Old-edged']
df2['AgeGroup'] = pd.cut(df2['age'], bins=bins, labels=labels, right=False)
df2['AgeGroup'].value_counts()
# Out:
# 0    809
# 1    500
# Name: survived, dtype: int64
# Adult           1068
# Under_18         136
# Middle-edged      97
# Old-edged          8
# Name: AgeGroup, dtype: int64

# %% [markdown]
# Above code creates a histogram of the age column in the DataFrame df2, and then creates a new column called AgeGroup that categorizes the ages into four groups: Under_18, Adult, Middle-edged, and Old-edged.
#
# The first line of code plots a histogram of the age column:
#
#
# df2['age'].plot(kind='hist')
#
# The histogram shows the distribution of the ages in the age column.
#
# The second line of code creates the bins variable:
# bins = [0, 18, 50, 70, 110]
# The bins variable defines the boundaries for the four age groups.
#
# The third line of code creates the labels variable:
#
# labels = ['Under_18', 'Adult', 'Middle-edged', 'Old-edged']
# The labels variable defines the labels for the four age groups.
#
# The fourth line of code creates the AgeGroup column:
#
# df2['AgeGroup'] = pd.cut(df2['age'], bins=bins, labels=labels, right=False)
# The pd.cut() function takes the age column, the bins variable, and the labels variable as arguments and returns a new column called AgeGroup that categorizes the ages into the four age groups.
#
# The right=False argument tells the pd.cut() function to include the rightmost bin boundary in the last group.
#
# The fifth line of code counts the number of people in each age group:
#
# df2['AgeGroup'].value_counts()

# %%
#Bivariant
sns.countplot(x='AgeGroup',hue='survived',data=df2)#2 CATE --> COUNTPLOT
#1 CAte and 1 numerical: Bargraph
#2 numerical :Scatterplot
sns.countplot(hue='sex',x='survived',data=df2)
#Adults and males were preffered less
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
a=df2.groupby(['survived'])
a.describe()
#Analysis
#3 types
#1.Taking a single col-->Univariant
#2.Taking 2 col --> Bivariant
#3.Taking 3 col--> Multivariant
# Out:
#          pclass                                                 age  \
#           count      mean       std  min  25%  50%  75%  max  count
# survived
# 0         809.0  2.500618  0.744825  1.0  2.0  3.0  3.0  3.0  809.0
# 1         500.0  1.962000  0.872972  1.0  1.0  2.0  3.0  3.0  500.0
#
#                      ... parch        fare                             \
#                mean  ...   75%  max  count       mean        std  min
# survived             ...
# 0         29.953745  ...   0.0  9.0  808.0  23.353831  34.145096  0.0
# 1         29.048180  ...   1.0  5.0  500.0  49.361184  68.648795  0.0
#
#
#               25%   50%    75%       max
# survived
# 0          7.8542  10.5  26.00  263.0000
# 1         11.2146  26.0  57.75  512.3292
#
# [2 rows x 40 columns]

# %%
q1=df2['fare'].quantile(0.25)

# %%
q1
# Out:
# 7.8958

# %%
q3=df2['fare'].quantile(0.75)

# %%
q3
iqr=q3-q1

# %%
lower=q1-(1.5*iqr)
upper=q3+(1.5*iqr)

# %%
lower
# Out:
# -27.172999999999995

# %%
upper
# Out:
# 66.34379999999999

# %%
#Data Analysis
#univariant analysis
#2 NATURE
#Continous--> histogram
#Discrete

# %%
df2['age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#15 to 45

bins= [0,2,4,13,20,50,70,110]
labels = ['Infant','Toddler','Kid','Teen','Adult','Middle-edged','Old-edged']
df2['AgeGroup'] = pd.cut(df2['age'], bins=bins, labels=labels, right=False)

# %%
df2['AgeGroup'].value_counts()
# Out:
# Adult           997
# Teen            123
# Middle-edged     97
# Kid              43
# Infant           22
# Toddler          19
# Old-edged         8
# Name: AgeGroup, dtype: int64

# %%
bins= [0,30,60,100,250,1000]
labels = ['Cheap','Average','Above Average','High','Expensive']
df2['Fare_Range'] = pd.cut(df2['fare'], bins=bins, labels=labels, right=False)

# %%
df2['Fare_Range'].value_counts()
df2['pclass'].value_counts()
df2['survived'].value_counts()#pie chart
mycolors = ["black", "hotpink", "b", "#4CAF50"]
plt.pie(df2['pclass'],colors=mycolors);

# %%
#Bi variant analysis
sns.countplot(hue='pclass',x='survived',data=df2)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(x='AgeGroup',hue='survived',data=df2)
# Out:
# <Axes: xlabel='AgeGroup', ylabel='count'>

# %%
#Mostly people were travelling on fare less than 30
#Most people were travelling on 3rd class
#Most people were from the age of 20 to 50
#Only 500 people survived

# %%
sns.countplot(x='sex',hue='survived',data=df2)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#15 insights ...
#Multivariant
sns.pairplot(data=df2)
